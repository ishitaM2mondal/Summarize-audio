# %%
# !pip install youtube-transcript-api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 7.3 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Replace with the YouTube video ID
video_id = "jiiPEAE1x5U&t=13s"

# Fetch transcript
try:
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    for entry in transcript:
        print(f"{entry['start']}: {entry['text']}")
except Exception as e:
    print("Error:", e)
# Out:
# 0.12: from Jammu and Kashmir where
# 1.8: preparations are underway for the
# 3.8: inauguration of the Rail Link connecting
# 5.839: Kashmir Valley with the rest of
# 7.92: India and of course the project is
# 10.4: nearing its completion with a final
# 12.639: inspection by the railway safety
# 14.639: commissioner expected before January 15
# 17.88: in fact viewers prime minister Narendra
# 19.76: Modi is likely to flag off the first W
# 22.16: Bharat train from Delhi to Shri nagar in
# 24.32: January the udhampur shagar baramula
# 27.519: rail project that started in 2020 uh
# 31.679: 2005 to6 includes India's longest rail
# 35.719: tunnel uh 12.75 km approximately and the
# 40.68: world's highest Railway arch bridge over
# 44.28: the chinab river 359 m above ground now
# 49.039: future plans include Vista dome trains
# 52.359: for panoramic views of the Himalayan
# 56.64: region let's go across to aravat who
# 59.68: join joining us and now arabat very good
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Replace with the YouTube video ID
video_id = "k9uzry8scwU"

# Fetch transcript
try:
    transcript = YouTubeTranscriptApi.get_transcript(video_id)

    # Combine all the text into a single paragraph
    transcript_text = " ".join(entry['text'] for entry in transcript)

    # Print the transcript as a paragraph
    print(transcript_text)
except Exception as e:
    print("Error:", str(e))
# Out:
# India's national capital New Delhi is getting out for State Assembly elections the upcoming polls are expected to be a fiercely contested battle between the leading Baria J party and the aadmi party while the arm admy party has already released the list of its candidates the BH J party has released its first list on Saturday the list also includes candidates for 29 seats are the total 70 seats in the Delhi assembly the former Bia J party Member of Parliament perves Singh Varma will be contesting against the former Delhi chief minister and the op convenor arind krial from the New Delhi seat another former BJP MP from South Delhi Ramesh biduri is in the freay where he's contesting from the Kaji constituency against the Delhi chief minister arshi the congress party is fielded alal lamba from Kaji constituency the B J party is fielded Sardar thinder Singh from Mara from jungpura constituency he spitted against the former Delhi deputy chief minister Manish sodia the Congress is also fed t
# ...

# %%
from transformers import pipeline

# %%
summarization = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
summarization_text = summarization(transcript_text)

# %%
summarization_text
# Out:
# [{'summary_text': " India's national capital New Delhi is getting out for State Assembly elections . The leading Baria J party and the aadmi party are expected to be a fiercely contested battle . The arm admy party has been in power in Delhi since 2015 having secured Landslide victories twice ."}]
